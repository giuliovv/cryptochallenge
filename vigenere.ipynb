# %%
from collections import Counter
import string

import pandas as pd

# %%
testo = "Klkbnqlcytfysryucocphgbdizzfcmjwkuchzyeswfogmmetwwossdchrzyldsbwnydednzwnefydthtddbojicemlucdygicczhoadrzcylwadsxpilpiecskomoltejtkmqqymehpmmjxyolwpeewjckznpccpsvsxauyodhalmriocwpelwbcniyfxmwjcemcyrazdqlsomdbfljwnbijxpddsyoehxpceswtoxwbleecsaxcnuetzywfn".lower()

# %%
chiave = "sskkuullll"

# %%
vigeneredf = pd.DataFrame([list(string.ascii_lowercase)[x:]+list(string.ascii_lowercase)[:x] for x in range(26)])
vigeneredf.index = list(string.ascii_lowercase)
vigeneredf.columns = list(string.ascii_lowercase)
vigenere = vigeneredf.to_dict()
vigeneredf
# Out:
#    a  b  c  d  e  f  g  h  i  j  ...  q  r  s  t  u  v  w  x  y  z
# a  a  b  c  d  e  f  g  h  i  j  ...  q  r  s  t  u  v  w  x  y  z
# b  b  c  d  e  f  g  h  i  j  k  ...  r  s  t  u  v  w  x  y  z  a
# c  c  d  e  f  g  h  i  j  k  l  ...  s  t  u  v  w  x  y  z  a  b
# d  d  e  f  g  h  i  j  k  l  m  ...  t  u  v  w  x  y  z  a  b  c
# e  e  f  g  h  i  j  k  l  m  n  ...  u  v  w  x  y  z  a  b  c  d
# f  f  g  h  i  j  k  l  m  n  o  ...  v  w  x  y  z  a  b  c  d  e
# g  g  h  i  j  k  l  m  n  o  p  ...  w  x  y  z  a  b  c  d  e  f
# h  h  i  j  k  l  m  n  o  p  q  ...  x  y  z  a  b  c  d  e  f  g
# i  i  j  k  l  m  n  o  p  q  r  ...  y  z  a  b  c  d  e  f  g  h
# j  j  k  l  m  n  o  p  q  r  s  ...  z  a  b  c  d  e  f  g  h  i
# k  k  l  m  n  o  p  q  r  s  t  ...  a  b  c  d  e  f  g  h  i  j
# l  l  m  n  o  p  q  r  s  t  u  ...  b  c  d  e  f  g  h  i  j  k
# m  m  n  o  p  q  r  s  t  u  v  ...  c  d  e  f  g  h  i  j  k  l
# ...

# %%
"".join([{b:a for a,b in vigenere[key].items()}[lettera] for key, lettera in zip(chiave*int(len(testo)/len(chiave)), testo)])
# Out:
# 'startwarningiheardreportofourbreakinonthenewsstillwaitingonalarmtestschedulesiwillreportbacktomorrowwithfinalplanforextrasecurityisuggestweburnourlettersafterreadingandswitchourletterstonumbersusingpolybiussquaredropmessageunderthebenchattrainstation'
